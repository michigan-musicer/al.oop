# %% [markdown]
# Tasks:
# - Set up a text generation model (recommended: Phi or GPT2)
# - Set up an audio generation model (recommended: Bark or VITS)
# - Create a program with the following control flow:
#   - user inputs text
#   - a response is generated by your text generation model
#   - an audio buffer / file is generated by the audio generation model
#   - program plays the audio buffer
#
# The best thing to do to start is to get example programs from HuggingFace working: take a look at the manpages for \__ and \__ and try to get the examples from those pages running. Once you accomplish that, you can write some more code to take user input and pass the result of text generation to audio generation.

# %% [markdown]
# When running, you may find it helpful to connect to a GPU instance. In the top-right of the Colab Notebook window, click the dropdown arrow next to "Connect" => "Change runtime type" => select T4. The Tesla T4 GPU card is 16 GB and is specifically designed to help with deep learning tasks.
#
# If you get stuck, you may need to restart your Python runtime: go to Runtime => Restart session.

# %%
# if you need to install packages with pip, use this code block.
# Syntax: %pip install <package name>

# %pip install accelerate

# %%
# If you need to import any packages, use this code block.
# Syntax: import <package name>

# %%
# Start here! For the sake of organization, I recommend creating separate code blocks for separate tasks.
